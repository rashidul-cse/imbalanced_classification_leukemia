# %% [markdown]
# # CLAHE applied

# %%
import numpy as np
import cv2
import os
import skimage
from skimage.io import imread, imshow
import json
from matplotlib import pyplot as plt
from PIL import Image, ImageEnhance

import cv2

def pre_processImg(img):
    
    #-----Reading the image-----------------------------------------------------
    #img = cv2.imread(r'E:\Leuk study re-designed\C-NMC\Low imbalance\Train - 1 to 10 ratio\hem\UID_H1_1_1_hem.bmp', 1)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #cv2.imshow("img",img) 

    #-----Converting image to LAB Color model----------------------------------- 
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    #cv2.imshow("lab",lab)

    #-----Splitting the LAB image to different channels-------------------------
    l, a, b = cv2.split(lab)
    #cv2.imshow('l_channel', l)
    #cv2.imshow('a_channel', a)
    #cv2.imshow('b_channel', b)

    #-----Applying CLAHE to L-channel-------------------------------------------
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    #cv2.imshow('CLAHE output', cl)

    #-----Merge the CLAHE enhanced L-channel with the a and b channel-----------
    limg = cv2.merge((cl,a,b))
    #cv2.imshow('limg', limg)

    #-----Converting image from LAB Color model to RGB model--------------------
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    print('Min max values: ', np.max(final), np.min(final), final.dtype)
    im = Image.fromarray(final)
    enhancer = ImageEnhance.Brightness(im)

    factor = 2.0 #gives original image
    im_output = enhancer.enhance(factor)

    return im_output #PIL -Image returning


path_src = r'F:\Leuk study re-designed\C-NMC\High Imbalance\Test\hem'
path_tgt = r'F:\Leuk study re-designed\C-NMC\High Imbalance\Test\enhanced\hem'

all_list = os.listdir(path_src)
for x in range(len(all_list)):
    img = cv2.imread(os.path.join(path_src, all_list[x]))
    img = pre_processImg(img)
    img.save(os.path.join(path_tgt, all_list[x]))
print('Success')
# Out:
# Min max values:  161 4 uint8
# Min max values:  168 4 uint8
# Min max values:  170 4 uint8
# Min max values:  166 4 uint8
# Min max values:  172 6 uint8
# Min max values:  172 6 uint8
# Min max values:  168 6 uint8
# Min max values:  173 6 uint8
# Min max values:  197 4 uint8
# Min max values:  160 4 uint8
# Min max values:  179 4 uint8
# Min max values:  184 4 uint8
# Min max values:  176 4 uint8
# Min max values:  154 6 uint8
# Min max values:  200 4 uint8
# Min max values:  160 4 uint8
# Min max values:  185 6 uint8
# Min max values:  186 4 uint8
# Min max values:  169 4 uint8
# Min max values:  190 6 uint8
# Min max values:  170 6 uint8
# Min max values:  185 4 uint8
# Min max values:  162 4 uint8
# Min max values:  167 4 uint8
# Min max values:  161 4 uint8
# Min max values:  193 4 uint8
# Min max values:  180 6 uint8
# Min max values:  164 6 uint8
# Min max values:  186 4 uint8
# Min max values:  172 4 uint8
# Min max values:  156 4 uint8
# Min max values:  151 4 uint8
# Min max values:  192 4 uint8
# Min max values:  166 4 uint8
# Min max values:  159 4 uint8
# Min max values:  158 4 uint8
# Min max values:  199 4 uint8
# Min max values:  168 4 uint8
# Min max values:  184 4 uint8
# Min max values:  204 4 uint8
# Min max values:  203 4 uint8
# Min max values:  163 4 uint8
# Min max values:  170 4 uint8
# Min max values:  170 4 uint8
# Min max values:  165 4 uint8
# Min max values:  184 4 uint8
# Min max values:  187 4 uint8
# Min max values:  176 4 uint8
# Min max values:  180 6 uint8
# Min max values:  175 4 uint8
# Min max values:  172 4 uint8
# Min max values:  180 4 uint8
# Min max values:  188 6 uint8
# Min max values:  188 4 uint8
# Min max values:  176 4 uint8
# Min max values:  168 4 uint8
# Min max values:  234 4 uint8
# Min max values:  167 4 uint8
# Min max values:  214 4 uint8
# Min max values:  163 4 uint8
# Min max values:  175 6 uint8
# Min max values:  195 4 uint8
# Min max values:  194 4 uint8
# Min max values:  195 4 uint8
# Min max values:  177 4 uint8
# Min max values:  209 4 uint8
# Min max values:  160 6 uint8
# Min max values:  159 4 uint8
# Min max values:  167 4 uint8
# Min max values:  215 4 uint8
# Min max values:  198 4 uint8
# Min max values:  180 4 uint8
# Min max values:  179 4 uint8
# Min max values:  185 4 uint8
# Min max values:  180 4 uint8
# Min max values:  161 4 uint8
# Min max values:  175 4 uint8
# Min max values:  193 4 uint8
# Min max values:  190 3 uint8
# Min max values:  213 4 uint8
# Min max values:  193 4 uint8
# Min max values:  218 4 uint8
# Min max values:  181 4 uint8
# Min max values:  154 4 uint8
# Min max values:  172 6 uint8
# Min max values:  158 6 uint8
# Min max values:  172 6 uint8
# Min max values:  167 4 uint8
# Min max values:  191 4 uint8
# Min max values:  208 4 uint8
# Min max values:  184 4 uint8
# Min max values:  163 4 uint8
# Min max values:  185 4 uint8
# Min max values:  187 4 uint8
# Min max values:  181 4 uint8
# Min max values:  171 4 uint8
# Min max values:  177 4 uint8
# Min max values:  154 4 uint8
# Min max values:  153 4 uint8
# Min max values:  179 4 uint8
# Min max values:  246 4 uint8
# Min max values:  179 4 uint8
# Min max values:  197 6 uint8
# Min max values:  172 4 uint8
# Min max values:  220 4 uint8
# Min max values:  179 4 uint8
# Min max values:  184 4 uint8
# Min max values:  181 4 uint8
# Min max values:  175 6 uint8
# Min max values:  191 4 uint8
# Min max values:  193 4 uint8
# Min max values:  172 4 uint8
# Min max values:  167 4 uint8
# Min max values:  180 6 uint8
# Min max values:  161 4 uint8
# Min max values:  162 4 uint8
# Min max values:  166 4 uint8
# Min max values:  174 6 uint8
# Min max values:  173 4 uint8
# Min max values:  197 4 uint8
# Min max values:  178 6 uint8
# Min max values:  174 4 uint8
# Min max values:  165 4 uint8
# Min max values:  187 4 uint8
# Min max values:  172 4 uint8
# Min max values:  184 4 uint8
# Min max values:  156 4 uint8
# Min max values:  197 4 uint8
# Min max values:  183 4 uint8
# Min max values:  163 4 uint8
# Min max values:  178 4 uint8
# Min max values:  218 4 uint8
# Min max values:  191 6 uint8
# Min max values:  188 4 uint8
# Min max values:  180 4 uint8
# Min max values:  184 4 uint8
# Min max values:  187 4 uint8
# Min max values:  170 4 uint8
# Min max values:  230 6 uint8
# Min max values:  183 4 uint8
# Min max values:  161 4 uint8
# Min max values:  158 4 uint8
# Min max values:  175 4 uint8
# Min max values:  172 4 uint8
# Min max values:  168 6 uint8
# Min max values:  188 4 uint8
# Min max values:  165 4 uint8
# Min max values:  177 6 uint8
# Min max values:  175 4 uint8
# Min max values:  191 4 uint8
# Min max values:  172 4 uint8
# Min max values:  191 4 uint8
# Min max values:  181 4 uint8
# Min max values:  186 4 uint8
# Min max values:  166 4 uint8
# Min max values:  184 4 uint8
# Min max values:  207 3 uint8
# Min max values:  191 4 uint8
# Min max values:  157 4 uint8
# Min max values:  162 4 uint8
# Min max values:  203 4 uint8
# Min max values:  185 4 uint8
# Min max values:  162 4 uint8
# Min max values:  165 4 uint8
# Min max values:  179 4 uint8
# Min max values:  181 3 uint8
# Min max values:  176 4 uint8
# Min max values:  159 4 uint8
# Min max values:  158 4 uint8
# Min max values:  192 4 uint8
# Min max values:  179 4 uint8
# Min max values:  165 6 uint8
# Min max values:  176 4 uint8
# Min max values:  197 6 uint8
# Min max values:  194 4 uint8
# Min max values:  182 4 uint8
# Min max values:  178 4 uint8
# Min max values:  176 6 uint8
# Min max values:  173 4 uint8
# Min max values:  174 4 uint8
# Min max values:  150 4 uint8
# Min max values:  171 4 uint8
# Min max values:  187 4 uint8
# Min max values:  180 4 uint8
# Min max values:  167 4 uint8
# Min max values:  212 3 uint8
# Min max values:  168 6 uint8
# Min max values:  179 4 uint8
# Min max values:  165 4 uint8
# Min max values:  172 4 uint8
# Min max values:  175 4 uint8
# Min max values:  163 4 uint8
# Min max values:  194 6 uint8
# Min max values:  167 4 uint8
# Min max values:  183 4 uint8
# Min max values:  192 4 uint8
# Min max values:  165 6 uint8
# Min max values:  174 4 uint8
# Min max values:  180 4 uint8
# Min max values:  157 4 uint8
# Min max values:  179 4 uint8
# Min max values:  168 6 uint8
# Min max values:  188 4 uint8
# Min max values:  166 4 uint8
# Min max values:  182 6 uint8
# Min max values:  177 3 uint8
# Min max values:  164 4 uint8
# Min max values:  187 4 uint8
# Min max values:  195 4 uint8
# Min max values:  175 4 uint8
# Min max values:  176 4 uint8
# Min max values:  198 6 uint8
# Min max values:  191 4 uint8
# Min max values:  182 4 uint8
# Min max values:  175 6 uint8
# Min max values:  184 6 uint8
# Min max values:  155 4 uint8
# Min max values:  174 3 uint8
# Min max values:  204 6 uint8
# Min max values:  181 4 uint8
# Min max values:  176 6 uint8
# Min max values:  171 4 uint8
# Min max values:  192 4 uint8
# Min max values:  152 4 uint8
# Min max values:  178 6 uint8
# Min max values:  190 4 uint8
# Min max values:  177 4 uint8
# Min max values:  168 4 uint8
# Min max values:  174 4 uint8
# Min max values:  175 6 uint8
# Min max values:  150 4 uint8
# Min max values:  180 4 uint8
# Min max values:  217 4 uint8
# Min max values:  164 6 uint8
# Min max values:  206 4 uint8
# Min max values:  174 6 uint8
# Min max values:  158 4 uint8
# Min max values:  165 4 uint8
# Min max values:  166 4 uint8
# Min max values:  165 6 uint8
# Min max values:  179 4 uint8
# Min max values:  177 4 uint8
# Min max values:  187 4 uint8
# Min max values:  187 4 uint8
# Min max values:  208 4 uint8
# Min max values:  167 4 uint8
# Min max values:  162 4 uint8
# Min max values:  169 4 uint8
# Min max values:  159 4 uint8
# Min max values:  172 3 uint8
# Min max values:  177 4 uint8
# Min max values:  178 4 uint8
# Min max values:  169 6 uint8
# Min max values:  154 3 uint8
# Min max values:  171 6 uint8
# Min max values:  172 4 uint8
# Min max values:  167 4 uint8
# Min max values:  214 4 uint8
# Min max values:  168 4 uint8
# Min max values:  174 6 uint8
# Min max values:  175 6 uint8
# Min max values:  206 6 uint8
# Min max values:  178 6 uint8
# Min max values:  168 6 uint8
# Min max values:  157 4 uint8
# Min max values:  195 4 uint8
# Min max values:  167 4 uint8
# Min max values:  176 4 uint8
# Min max values:  178 4 uint8
# Min max values:  181 4 uint8
# Min max values:  175 4 uint8
# Min max values:  165 6 uint8
# Min max values:  185 4 uint8
# Min max values:  164 4 uint8
# Min max values:  191 4 uint8
# Min max values:  166 4 uint8
# Min max values:  185 6 uint8
# Min max values:  190 4 uint8
# Min max values:  169 4 uint8
# Min max values:  183 6 uint8
# Min max values:  173 4 uint8
# Min max values:  169 4 uint8
# Min max values:  166 4 uint8
# Min max values:  166 4 uint8
# Min max values:  179 4 uint8
# Min max values:  175 4 uint8
# Min max values:  179 4 uint8
# Min max values:  184 6 uint8
# Min max values:  171 6 uint8
# Min max values:  165 4 uint8
# Min max values:  145 4 uint8
# Min max values:  165 4 uint8
# Min max values:  177 6 uint8
# Min max values:  162 4 uint8
# Min max values:  182 4 uint8
# Min max values:  190 6 uint8
# Min max values:  185 4 uint8
# Min max values:  167 6 uint8
# Min max values:  177 4 uint8
# Min max values:  196 4 uint8
# Min max values:  169 4 uint8
# Min max values:  166 6 uint8
# Min max values:  186 4 uint8
# Min max values:  177 4 uint8
# Min max values:  164 4 uint8
# Min max values:  178 4 uint8
# Min max values:  160 4 uint8
# Min max values:  159 4 uint8
# Min max values:  159 4 uint8
# Min max values:  171 4 uint8
# Min max values:  160 4 uint8
# Min max values:  169 4 uint8
# Min max values:  165 3 uint8
# Min max values:  193 4 uint8
# Min max values:  206 5 uint8
# Min max values:  193 4 uint8
# Min max values:  183 4 uint8
# Min max values:  160 4 uint8
# Min max values:  176 4 uint8
# Min max values:  173 4 uint8
# Min max values:  162 4 uint8
# Min max values:  163 4 uint8
# Min max values:  190 3 uint8
# Min max values:  162 4 uint8
# Min max values:  200 4 uint8
# Min max values:  171 4 uint8
# Min max values:  169 4 uint8
# Min max values:  179 4 uint8
# Min max values:  178 4 uint8
# Min max values:  199 4 uint8
# Min max values:  166 6 uint8
# Min max values:  179 4 uint8
# Min max values:  158 6 uint8
# Min max values:  176 6 uint8
# Min max values:  173 4 uint8
# Min max values:  169 4 uint8
# Min max values:  175 4 uint8
# Min max values:  175 4 uint8
# Min max values:  205 4 uint8
# Min max values:  194 6 uint8
# Min max values:  162 6 uint8
# Min max values:  171 4 uint8
# Min max values:  211 3 uint8
# Min max values:  167 4 uint8
# Min max values:  169 4 uint8
# Min max values:  183 4 uint8
# Min max values:  197 4 uint8
# Min max values:  183 4 uint8
# Min max values:  191 4 uint8
# Min max values:  171 6 uint8
# Min max values:  181 4 uint8
# Min max values:  166 6 uint8
# Min max values:  187 4 uint8
# Min max values:  177 4 uint8
# Min max values:  165 4 uint8
# Min max values:  191 4 uint8
# Min max values:  175 4 uint8
# Min max values:  177 4 uint8
# Min max values:  166 4 uint8
# Min max values:  186 6 uint8
# Min max values:  155 4 uint8
# Min max values:  182 6 uint8
# Min max values:  197 3 uint8
# Min max values:  202 4 uint8
# Min max values:  179 4 uint8
# Min max values:  175 6 uint8
# Min max values:  178 6 uint8
# Min max values:  181 6 uint8
# Min max values:  196 4 uint8
# Min max values:  160 6 uint8
# Min max values:  172 4 uint8
# Min max values:  198 4 uint8
# Min max values:  173 4 uint8
# Min max values:  198 4 uint8
# Min max values:  190 4 uint8
# Min max values:  179 4 uint8
# Min max values:  185 4 uint8
# Min max values:  203 3 uint8
# Min max values:  188 6 uint8
# Min max values:  174 4 uint8
# Min max values:  175 6 uint8
# Min max values:  172 4 uint8
# Min max values:  219 4 uint8
# Min max values:  179 4 uint8
# Min max values:  174 4 uint8
# Min max values:  202 4 uint8
# Min max values:  162 4 uint8
# Min max values:  198 6 uint8
# Min max values:  173 4 uint8
# Min max values:  179 6 uint8
# Min max values:  183 4 uint8
# Min max values:  171 4 uint8
# Min max values:  159 4 uint8
# Min max values:  179 6 uint8
# Min max values:  166 4 uint8
# Min max values:  230 4 uint8
# Min max values:  178 4 uint8
# Min max values:  185 4 uint8
# Min max values:  175 4 uint8
# Min max values:  173 6 uint8
# Min max values:  177 4 uint8
# Min max values:  170 6 uint8
# Min max values:  196 4 uint8
# Min max values:  171 6 uint8
# Min max values:  166 6 uint8
# Min max values:  182 4 uint8
# Min max values:  158 4 uint8
# Min max values:  173 4 uint8
# Min max values:  176 4 uint8
# Min max values:  170 4 uint8
# Min max values:  175 4 uint8
# Min max values:  163 3 uint8
# Min max values:  188 4 uint8
# Min max values:  171 6 uint8
# Min max values:  181 4 uint8
# Min max values:  214 4 uint8
# Min max values:  196 4 uint8
# Min max values:  173 4 uint8
# Min max values:  161 6 uint8
# Min max values:  172 4 uint8
# Min max values:  178 4 uint8
# Min max values:  161 4 uint8
# Min max values:  179 4 uint8
# Min max values:  169 6 uint8
# Min max values:  186 6 uint8
# Min max values:  169 4 uint8
# Min max values:  177 4 uint8
# Min max values:  170 4 uint8
# Min max values:  194 6 uint8
# Min max values:  164 4 uint8
# Min max values:  195 4 uint8
# Min max values:  219 4 uint8
# Min max values:  160 6 uint8
# Min max values:  216 4 uint8
# Min max values:  182 4 uint8
# Min max values:  161 4 uint8
# Min max values:  184 4 uint8
# Min max values:  180 3 uint8
# Min max values:  179 4 uint8
# Min max values:  165 4 uint8
# Min max values:  180 4 uint8
# Min max values:  159 4 uint8
# Min max values:  209 6 uint8
# Min max values:  187 6 uint8
# Min max values:  176 6 uint8
# Min max values:  176 4 uint8
# Min max values:  195 4 uint8
# Min max values:  192 4 uint8
# Min max values:  174 6 uint8
# Min max values:  188 4 uint8
# Min max values:  194 4 uint8
# Min max values:  154 4 uint8
# Min max values:  181 4 uint8
# Min max values:  171 4 uint8
# Min max values:  178 6 uint8
# Min max values:  180 4 uint8
# Min max values:  177 4 uint8
# Min max values:  197 4 uint8
# Min max values:  179 4 uint8
# Min max values:  157 4 uint8
# Min max values:  190 4 uint8
# Min max values:  156 4 uint8
# Min max values:  171 4 uint8
# Min max values:  176 4 uint8
# Min max values:  172 4 uint8
# Min max values:  203 4 uint8
# Min max values:  172 4 uint8
# Min max values:  168 4 uint8
# Min max values:  203 4 uint8
# Min max values:  168 4 uint8
# Min max values:  155 4 uint8
# Min max values:  177 4 uint8
# Min max values:  181 4 uint8
# Min max values:  183 4 uint8
# Min max values:  181 4 uint8
# Min max values:  149 4 uint8
# Min max values:  173 6 uint8
# Min max values:  232 4 uint8
# Min max values:  212 4 uint8
# Min max values:  171 6 uint8
# Min max values:  204 4 uint8
# Min max values:  186 4 uint8
# Min max values:  165 4 uint8
# Min max values:  180 6 uint8
# Min max values:  152 4 uint8
# Min max values:  177 6 uint8
# Min max values:  231 6 uint8
# Min max values:  157 6 uint8
# Min max values:  166 4 uint8
# Min max values:  230 4 uint8
# Min max values:  165 4 uint8
# Min max values:  176 4 uint8
# Min max values:  193 4 uint8
# Min max values:  182 6 uint8
# Min max values:  160 6 uint8
# Min max values:  187 4 uint8
# Min max values:  164 6 uint8
# Min max values:  162 4 uint8
# Min max values:  201 4 uint8
# Min max values:  164 4 uint8
# Min max values:  166 4 uint8
# Min max values:  180 4 uint8
# Min max values:  161 4 uint8
# Min max values:  179 4 uint8
# Min max values:  175 4 uint8
# Min max values:  160 4 uint8
# Min max values:  193 4 uint8
# Min max values:  195 4 uint8
# Min max values:  185 6 uint8
# Min max values:  158 4 uint8
# Min max values:  186 3 uint8
# Min max values:  186 4 uint8
# Min max values:  177 4 uint8
# Min max values:  184 4 uint8
# Min max values:  190 4 uint8
# Min max values:  197 4 uint8
# Min max values:  164 6 uint8
# Min max values:  175 4 uint8
# Min max values:  177 6 uint8
# Min max values:  173 4 uint8
# Min max values:  172 4 uint8
# Min max values:  186 4 uint8
# Min max values:  169 4 uint8
# Min max values:  187 4 uint8
# Min max values:  163 6 uint8
# Min max values:  194 4 uint8
# Min max values:  168 4 uint8
# Min max values:  187 4 uint8
# Min max values:  185 4 uint8
# Min max values:  170 4 uint8
# Min max values:  162 4 uint8
# Min max values:  181 3 uint8
# Min max values:  171 4 uint8
# Min max values:  178 6 uint8
# Min max values:  210 4 uint8
# Min max values:  172 4 uint8
# Min max values:  183 4 uint8
# Min max values:  169 4 uint8
# Min max values:  211 4 uint8
# Min max values:  162 6 uint8
# Min max values:  188 4 uint8
# Min max values:  169 4 uint8
# Min max values:  170 6 uint8
# Min max values:  187 4 uint8
# Min max values:  214 4 uint8
# Min max values:  181 6 uint8
# Min max values:  155 4 uint8
# Min max values:  162 4 uint8
# Min max values:  159 4 uint8
# Min max values:  169 4 uint8
# Min max values:  177 6 uint8
# Min max values:  149 4 uint8
# Min max values:  161 6 uint8
# Min max values:  162 4 uint8
# Min max values:  223 3 uint8
# Min max values:  179 4 uint8
# Min max values:  180 4 uint8
# Min max values:  185 6 uint8
# Min max values:  170 4 uint8
# Min max values:  164 4 uint8
# Min max values:  152 4 uint8
# Min max values:  169 6 uint8
# Min max values:  168 4 uint8
# Min max values:  192 4 uint8
# Min max values:  168 4 uint8
# Min max values:  191 4 uint8
# Min max values:  161 4 uint8
# Min max values:  160 4 uint8
# Min max values:  170 4 uint8
# Min max values:  170 4 uint8
# Min max values:  168 4 uint8
# Min max values:  183 4 uint8
# Min max values:  197 4 uint8
# Min max values:  181 6 uint8
# Min max values:  162 4 uint8
# Min max values:  149 6 uint8
# Min max values:  173 4 uint8
# Min max values:  206 4 uint8
# Min max values:  183 6 uint8
# Min max values:  175 4 uint8
# Min max values:  181 4 uint8
# Min max values:  197 4 uint8
# Min max values:  168 6 uint8
# Min max values:  167 6 uint8
# Min max values:  170 6 uint8
# Min max values:  174 4 uint8
# Min max values:  189 4 uint8
# Min max values:  179 6 uint8
# Min max values:  190 4 uint8
# Min max values:  178 4 uint8
# Min max values:  169 4 uint8
# Min max values:  174 4 uint8
# Min max values:  148 6 uint8
# Min max values:  192 4 uint8
# Min max values:  189 6 uint8
# Min max values:  180 6 uint8
# Min max values:  190 4 uint8
# Min max values:  190 4 uint8
# Min max values:  172 4 uint8
# Min max values:  182 3 uint8
# Min max values:  174 4 uint8
# Min max values:  163 4 uint8
# Min max values:  162 4 uint8
# Min max values:  166 4 uint8
# Min max values:  177 4 uint8
# Min max values:  174 4 uint8
# Min max values:  176 4 uint8
# Min max values:  198 3 uint8
# Min max values:  170 4 uint8
# Min max values:  194 4 uint8
# Min max values:  161 4 uint8
# Min max values:  165 6 uint8
# Min max values:  171 3 uint8
# Min max values:  159 4 uint8
# Min max values:  185 6 uint8
# Min max values:  167 4 uint8
# Min max values:  160 4 uint8
# Min max values:  174 4 uint8
# Min max values:  183 4 uint8
# Min max values:  205 6 uint8
# Min max values:  178 4 uint8
# Min max values:  166 4 uint8
# Min max values:  188 4 uint8
# Min max values:  176 6 uint8
# Min max values:  158 4 uint8
# Min max values:  173 4 uint8
# Min max values:  166 4 uint8
# Min max values:  180 4 uint8
# Min max values:  186 4 uint8
# Min max values:  163 4 uint8
# Min max values:  182 4 uint8
# Min max values:  191 6 uint8
# Min max values:  178 6 uint8
# Min max values:  177 6 uint8
# Min max values:  181 4 uint8
# Min max values:  165 6 uint8
# Min max values:  185 4 uint8
# Min max values:  174 4 uint8
# Min max values:  175 4 uint8
# Min max values:  158 6 uint8
# Min max values:  161 6 uint8
# Min max values:  165 6 uint8
# Min max values:  210 4 uint8
# Min max values:  173 4 uint8
# Min max values:  192 6 uint8
# Min max values:  163 4 uint8
# Min max values:  171 6 uint8
# Min max values:  183 6 uint8
# Success
